# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="10%">
#             <img src="homework.png">
#         </td>
#         <td>
#             <div align="center">
#                 <font color="#21618C" size=8px>
#                     <b>Take - home
#                         <br> (Day 3)
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### Let's begin with some hands-on practice exercises.
#
# **Create a dataframe wherever necessary**

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 1. Compute minimum and maximum sales for each store and location
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Store</th>
# <th>Location</th>
# <th>Sales</th>
# </tr>
# <tr>
# <td>A</td>
# <td>Mumbai</td>
# <td>40000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>45000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Hyderabad</td>
# <td>50000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>90000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Pune</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Delhi</td>
# <td>87000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Hyderabad</td>
# <td>85000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Pune</td>
# <td>78000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>70000</td>
# </tr>
#
# </table>

# %%
import numpy as np
import pandas as pd

# %%
data = [
    ['A','Mumbai',40000],
    ['B','Pune',45000],
    ['A','Hyderabad',50000],
    ['C','Mumbai',90000],
    ['D','Pune',89000],
    ['A','Delhi',87000],
    ['D','Hyderabad',85000],
    ['A','Pune',78000],
    ['C','Mumbai',89000],
    ['B','Pune',70000]
]
col=['Store','Location','Sales']
df=pd.DataFrame(data,columns=col)
pd.pivot_table(df,values='Sales',index='Store',columns='Location',aggfunc=[np.min,np.max])
# Out:
#              amin                                 amax                     \
# Location    Delhi Hyderabad   Mumbai     Pune    Delhi Hyderabad   Mumbai
# Store
# A         87000.0   50000.0  40000.0  78000.0  87000.0   50000.0  40000.0
# B             NaN       NaN      NaN  45000.0      NaN       NaN      NaN
# C             NaN       NaN  89000.0      NaN      NaN       NaN  90000.0
# D             NaN   85000.0      NaN  89000.0      NaN   85000.0      NaN
#
#
# Location     Pune
# Store
# A         78000.0
# B         70000.0
# C             NaN
# D         89000.0

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 2. Find duplicate rows based on the column 'Name'
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Name</th>
# <th>Salary</th>
# <th>City</th>
# </tr>
# <tr>
# <td>John</td>
# <td>3400</td>
# <td>Sydeny</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
# <tr>
# <td>Aadi</td>
# <td>1600</td>
# <td>New York</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Texas</td>
# </tr>
# <tr>
# <td>Aadi</td>
# <td>4000</td>
# <td>London</td>
# </tr>
# <tr>
# <td>Sachin</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
#
# </table>

# %%
df=pd.DataFrame({'Name':['John','Robert','Aadi','Robert','Robert','Robert','Aadi','Sachine'],'Salary':[3400,3000,1600,3000,3000,3000,4000,3000],'City':['Sydney','Chicago','NewYork','Chicago','Chicago','Texas','London','Chicago']})
df[df.duplicated(subset='Name')]
# Out:
#      Name  Salary     City
# 3  Robert    3000  Chicago
# 4  Robert    3000  Chicago
# 5  Robert    3000    Texas
# 6    Aadi    4000   London

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 3.  In column tournament, replace all the 'football' values  with 'cricket' using numpy.where
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
#
# <table>
# <tr>
# <th>Days</th>
# <th>Tournament</th>
# </tr>
# <tr>
# <td>Mon</td>
# <td>Football</td>
# </tr>
# <tr>
# <td>Tues</td>
# <td>Cricket</td>
# </tr>
# <tr>
# <td>Wed</td>
# <td>Football</td>
# </tr>
# <tr>
# <td>Thurs</td>
# <td>Football</td>
# </tr>
# <tr>
# <td>Fri</td>
# <td>Cricket</td>
# </tr>
#
# </table>

# %%
df=pd.DataFrame({'Days':['Mon','Tues','Wed','Thurs','Fri'],'Tournament':['Football','Cricket','Football','Football','Cricket']})
x = np.where(df['Tournament'] == 'Football')
df.loc[x[0], 'Tournament'] = 'Cricket'
df
# Out:
#     Days Tournament
# 0    Mon    Cricket
# 1   Tues    Cricket
# 2    Wed    Cricket
# 3  Thurs    Cricket
# 4    Fri    Cricket

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 4. Get the descriptive statistics of the sales for each season
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Month</th>
# <th>Sales</th>
# <th>Seasons</th>
# </tr>
# <tr>
# <td>Jan</td>
# <td>22000</td>
# <td>Winter</td>
# </tr>
# <tr>
# <td>Feb</td>
# <td>27000</td>
# <td>Winter</td>
# </tr>
# <tr>
# <td>Mar</td>
# <td>25000</td>
# <td>Spring</td>
# </tr>
# <tr>
# <td>Apr</td>
# <td>29000</td>
# <td>Spring</td>
# </tr>
# <tr>
# <td>May</td>
# <td>35000</td>
# <td>Spring</td>
# </tr>
# <tr>
# <td>June</td>
# <td>67000</td>
# <td>Summer</td>
# </tr>
# <tr>
# <td>July</td>
# <td>78000</td>
# <td>Summer</td>
# </tr>
# <tr>
# <td>Aug</td>
# <td>67000</td>
# <td>Summer</td>
# </tr>
# <tr>
# <td>Sep</td>
# <td>56000</td>
# <td>Fall</td>
# </tr>
# <tr>
# <td>Oct</td>
# <td>56000</td>
# <td>Fall</td>
# </tr>
# <tr>
# <td>Nov</td>
# <td>56000</td>
# <td>Fall</td>
# </tr>
# <tr>
# <td>Dec</td>
# <td>60000</td>
# <td>Winter</td>
# </tr>
#
# </table>

# %%
df=pd.DataFrame({'Month':['Jan','Feb','Mar','Apr','May','June','July','Aug','Sep','Oct','Nov','Dec'],'Sales':[22000,27000,25000,29000,35000,67000,78000,67000,56000,56000,56000,60000],'Seasons':['Winter','Winter','Spring','Spring','Spring','Summer','Summer','Summer','Fall','Fall','Fall','Winter']})
df['Sales'].groupby(df['Seasons']).describe()
# Out:
#          count          mean           std      min      25%      50%  \
# Seasons
# Fall       3.0  56000.000000      0.000000  56000.0  56000.0  56000.0
# Spring     3.0  29666.666667   5033.222957  25000.0  27000.0  29000.0
# Summer     3.0  70666.666667   6350.852961  67000.0  67000.0  67000.0
# Winter     3.0  36333.333333  20647.840888  22000.0  24500.0  27000.0
#
#              75%      max
# Seasons
# Fall     56000.0  56000.0
# Spring   32000.0  35000.0
# Summer   72500.0  78000.0
# Winter   43500.0  60000.0

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 5. Create a new column age with values of your choice. And append it to the below dataframe.
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Name</th>
# <th>Maths</th>
# <th>Science</th>
# <th>English</th>
# </tr>
# <tr>
# <td>Emma</td>
# <td>56</td>
# <td>89</td>
# <td>89</td>
# </tr>
# <tr>
# <td>Mia</td>
# <td>78</td>
# <td>87</td>
# <td>89</td>
# </tr>
# <tr>
# <td>Sophia</td>
# <td>78</td>
# <td>78</td>
# <td>76</td>
# </tr>
# <tr>
# <td>James</td>
# <td>67</td>
# <td>89</td>
# <td>78</td>
# </tr>
# <td>John</td>
# <td>88</td>
# <td>78</td>
# <td>87</td>
# </tr>
#
# </table>

# %%
df=pd.DataFrame({'Name':['Emma','Mia','Sophia','James','John'],'Maths':[56,78,78,67,88],'Science':[89,87,78,89,78],'English':[89,89,76,78,87]})
df['Age']=[21,54,10,36,6]
df
# Out:
#      Name  Maths  Science  English  Age
# 0    Emma     56       89       89   21
# 1     Mia     78       87       89   54
# 2  Sophia     78       78       76   10
# 3   James     67       89       78   36
# 4    John     88       78       87    6

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 6. Perform right join to combine values based on the columns 'MA(Hons)' and 'Stud_ID' in the two dataframes
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
#     <tr>
#         <th>Stud_ID</th>
#         <th>Name</th>
#         <th>MA(Hons)</th>
#     </tr>
#     <tr>
#         <td>101</td>
#         <td>Alex</td>
#         <td>History</td>
#     </tr>
#     <tr>
#         <td>102</td>
#         <td>Amy</td>
#         <td>English</td>
#     </tr>
#     <tr>
#         <td>103</td>
#         <td>Allen</td>
#         <td>Geography</td>
#     </tr>
#     <tr>
#         <td>104</td>
#         <td>Alice</td>
#         <td>German</td>
#     </tr>
#         <td>105</td>
#         <td>James</td>
#         <td>History</td>
#     </tr>
# </table>
# <br>
#
#
#
# <table>
#     <tr>
#         <th>Stud_ID</th>
#         <th>Res_City</th>
#         <th>MA(Hons)</th>
#     </tr>
#     <tr>
#         <td>101</td>
#         <td>Delhi</td>
#         <td>English</td>
#     </tr>
#     <tr>
#         <td>102</td>
#         <td>Mumbai</td>
#         <td>History</td>
#     </tr>
#     <tr>
#         <td>103</td>
#         <td>Delhi</td>
#         <td>Fine Arts</td>
#     </tr>
#     <tr>
#         <td>104</td>
#         <td>Chennai</td>
#         <td>German</td>
#     </tr>
#         <td>105</td>
#         <td>Hyderabad</td>
#         <td>History</td>
#     </tr>
# </table>

# %%
df1=pd.DataFrame({'Stud_ID':[101,102,103,104,105],'Name':['Alex','Amy','Allen','Alice','James'],'MA(Hons)':['History','English','Geography','German','History']})
df2=pd.DataFrame({'Stud_ID':[101,102,103,104,105],'Res_city':['Delhi','Mumbai','Delhi','Chennai','Hyderabad'],'MA(Hons)':['English','History','Fine Arts','German','History']})
pd.merge(df1,df2,on=['MA(Hons)','Stud_ID'],how='right')
# Out:
#    Stud_ID   Name   MA(Hons)   Res_city
# 0      104  Alice     German    Chennai
# 1      105  James    History  Hyderabad
# 2      101    NaN    English      Delhi
# 3      102    NaN    History     Mumbai
# 4      103    NaN  Fine Arts      Delhi

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 7. Using the dataframes created in question 6, perform inner join to combine values based on the columns 'MA(Hons)' and 'Stud_ID' in the two dataframes
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# Write your code here

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 8. Concatenate two dataframes along the columns
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
#     <tr>
#         <th>Stud_ID</th>
#         <th>Name</th>
#     </tr>
#     <tr>
#         <td>101</td>
#         <td>Alex</td>
#     </tr>
#     <tr>
#         <td>102</td>
#         <td>Amy</td>
#     </tr>
#     <tr>
#         <td>103</td>
#         <td>Allen</td>
#     <tr>
#         <td>104</td>
#         <td>Alice</td>
#     </tr>
#         <td>105</td>
#         <td>James</td>
#     </tr>
# </table>
# <br>
#
#
#
# <table>
#     <tr>
#         <th>Res_City</th>
#         <th>MA(Hons)</th>
#     </tr>
#     <tr>
#         <td>Delhi</td>
#         <td>English</td>
#     </tr>
#     <tr>
#         <td>Mumbai</td>
#         <td>History</td>
#     </tr>
#     <tr>
#         <td>Delhi</td>
#         <td>Fine Arts</td>
#     </tr>
#     <tr>
#         <td>Chennai</td>
#         <td>German</td>
#     </tr>
#         <td>Hyderabad</td>
#         <td>History</td>
#     </tr>
# </table>

# %%
df1=pd.DataFrame({'Stud_ID':[101,102,103,104,105],'Name':['Alex','Amy','Allen','Alice','James']})
df2=pd.DataFrame({'Res_city':['Delhi','Mumbai','Delhi','Chennai','Hyderabad'],'MA(Hons)':['English','History','Fine Arts','German','History']})
df=pd.concat(objs=(df1,df2),axis=1,join='outer',ignore_index = True)
df
# Out:
#      0      1          2          3
# 0  101   Alex      Delhi    English
# 1  102    Amy     Mumbai    History
# 2  103  Allen      Delhi  Fine Arts
# 3  104  Alice    Chennai     German
# 4  105  James  Hyderabad    History

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 9. Calculate minimum, maximum and average sales for each season
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>ID</th>
# <th>Name</th>
# <th>Subject</th>
# </tr>
# <tr>
# <td>101</td>
# <td>Alex</td>
# <td>Maths</td>
# </tr>
# <tr>
# <td>102</td>
# <td>Amy</td>
# <td>English</td>
# </tr>
# <tr>
# <td>103</td>
# <td>Allen</td>
# <td>Science</td>
# </tr>
# <tr>
# <td>104</td>
# <td>Alice</td>
# <td>German</td>
# </tr>
# <td>105</td>
# <td>Ayoung</td>
# <td>History</td>
# </tr>
#
# </table><br>
#
#
#
# <table>
# <tr>
# <th>ID</th>
# <th>Name</th>
# <th>Subject</th>
# </tr>
# <tr>
# <td>101</td>
# <td>Billy</td>
# <td>English</td>
# </tr>
# <tr>
# <td>102</td>
# <td>Brian</td>
# <td>Science</td>
# </tr>
# <tr>
# <td>103</td>
# <td>Bran</td>
# <td>Social Science</td>
# </tr>
# <tr>
# <td>104</td>
# <td>Bryce</td>
# <td>German</td>
# </tr>
# <td>105</td>
# <td>Betty</td>
# <td>History</td>
# </tr>
#
# </table>

# %%
df=pd.DataFrame({'Month':['Jan','Feb','Mar','Apr','May','June','July','Aug','Sep','Oct','Nov','Dec'],'Sales':[22000,27000,25000,29000,35000,67000,78000,67000,56000,56000,56000,60000],'Seasons':['Winter','Winter','Spring','Spring','Spring','Summer','Summer','Summer','Fall','Fall','Fall','Winter']})
pd.pivot_table(df,values='Sales',index='Seasons',columns='Month',aggfunc=[np.min,np.max,'mean'])
# Out:
#             amin                                                        \
# Month        Apr      Aug      Dec      Feb      Jan     July     June
# Seasons
# Fall         NaN      NaN      NaN      NaN      NaN      NaN      NaN
# Spring   29000.0      NaN      NaN      NaN      NaN      NaN      NaN
# Summer       NaN  67000.0      NaN      NaN      NaN  78000.0  67000.0
# Winter       NaN      NaN  60000.0  27000.0  22000.0      NaN      NaN
#
#                                     ...     mean                             \
# Month        Mar      May      Nov  ...      Dec      Feb      Jan     July
# Seasons                             ...
# Fall         NaN      NaN  56000.0  ...      NaN      NaN      NaN      NaN
# Spring   25000.0  35000.0      NaN  ...      NaN      NaN      NaN      NaN
# Summer       NaN      NaN      NaN  ...      NaN      NaN      NaN  78000.0
# Winter       NaN      NaN      NaN  ...  60000.0  27000.0  22000.0      NaN
#
#
# ...

# %%
df=pd.DataFrame({'Month':['Jan','Feb','Mar','Apr','May','June','July','Aug','Sep','Oct','Nov','Dec'],'Sales':[22000,27000,25000,29000,35000,67000,78000,67000,56000,56000,56000,60000],'Seasons':['Winter','Winter','Spring','Spring','Spring','Summer','Summer','Summer','Fall','Fall','Fall','Winter']})
dff=df['Sales'].groupby(df['Seasons'])
print(dff.min())
print(dff.max())
print(dff.mean())
# Out:
# Seasons
# Fall      56000
# Spring    25000
# Summer    67000
# Winter    22000
# Name: Sales, dtype: int64
# Seasons
# Fall      56000
# Spring    35000
# Summer    78000
# Winter    60000
# Name: Sales, dtype: int64
# Seasons
# Fall      56000.000000
# Spring    29666.666667
# Summer    70666.666667
# Winter    36333.333333
# Name: Sales, dtype: float64

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 10. Find all the duplicate entries based on the columns X and Y.
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>X</th>
# <th>Y</th>
# <th>Z</th>
# </tr>
# <tr>
# <td>1</td>
# <td>2</td>
# <td>5</td>
# </tr>
# <tr>
# <td>2</td>
# <td>2</td>
# <td>6</td>
# </tr>
# <tr>
# <td>3</td>
# <td>1</td>
# <td>2</td>
# </tr>
# <tr>
# <td>1</td>
# <td>2</td>
# <td>6</td>
# </tr>
# <tr>
# <td>2</td>
# <td>2</td>
# <td>1</td>
# </tr>
# <tr>
# <td>3</td>
# <td>4</td>
# <td>6</td>
# </tr>
# <tr>
# <td>2</td>
# <td>2</td>
# <td>2</td>
# </tr>
# <tr>
# <td>2</td>
# <td>2</td>
# <td>8</td>
# </tr>
#
# </table>

# %%
df=pd.DataFrame({'X':[1,2,3,1,2,3,2,2],'Y':[2,2,1,2,2,4,2,2],'Z':[5,6,2,6,1,6,2,8]})
df[df.duplicated(subset=['X','Y'])]
# Out:
#    X  Y  Z
# 3  1  2  6
# 4  2  2  1
# 6  2  2  2
# 7  2  2  8

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Month</th>
# <th>Sales</th>
# <th>Seasons</th>
# </tr>
# <tr>
# <td>Jan</td>
# <td>22000</td>
# <td>Winter</td>
# </tr>
# <tr>
# <td>Feb</td>
# <td>27000</td>
# <td>Winter</td>
# </tr>
# <tr>
# <td>Mar</td>
# <td>25000</td>
# <td>Spring</td>
# </tr>
# <tr>
# <td>Apr</td>
# <td>29000</td>
# <td>Spring</td>
# </tr>
# <tr>
# <td>May</td>
# <td>35000</td>
# <td>Spring</td>
# </tr>
# <tr>
# <td>June</td>
# <td>67000</td>
# <td>Summer</td>
# </tr>
# <tr>
# <td>July</td>
# <td>78000</td>
# <td>Summer</td>
# </tr>
# <tr>
# <td>Aug</td>
# <td>67000</td>
# <td>Summer</td>
# </tr>
# <tr>
# <td>Sep</td>
# <td>56000</td>
# <td>Fall</td>
# </tr>
# <tr>
# <td>Oct</td>
# <td>56000</td>
# <td>Fall</td>
# </tr>
# <tr>
# <td>Nov</td>
# <td>56000</td>
# <td>Fall</td>
# </tr>
# <tr>
# <td>Dec</td>
# <td>60000</td>
# <td>Winter</td>
# </tr>
#
# </table>

# %%
df1=pd.DataFrame({'ID':[101,102,103,104,105],'Name':['Alex','Amy','Allen','Alice','Ayoung'],'Subject':['Maths','English','Science','German','History']})
df2=pd.DataFrame({'ID':[101,102,103,104,105],'Name':['Billy','Brian','Bran','Bryce','Betty'],'Subject':['English','Science','Social Science','German','History']})
