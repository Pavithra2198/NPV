# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="10%">
#             <img src="in_class.png">
#         </td>
#         <td>
#             <div align="center">
#                 <font color="#21618C" size=8px>
#                     <b>Inclass - Lab<br> (Day 3)
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## Table of Content
#
# 1. **[Pivot Table](#Pivoting)**
# 2. **[Duplicate](#Duplicating)**
# 3. **[Replace](#Replacing)**
# 4. **[Summary Statistics](#Summary_Statistics)**
# 5. **[Merge, Join, Concatenate](#merge)**

# %% [markdown]
# **Let us import the required library**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Let's begin with some hands-on practice exercises

# %% [markdown]
# <a id='Pivoting'></a>
# ## 1. Pivot Table

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 3. Find the average sales for each store
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Store</th>
# <th>Location</th>
# <th>Sales</th>
# </tr>
# <tr>
# <td>A</td>
# <td>Mumbai</td>
# <td>40000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>45000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Hyderabad</td>
# <td>50000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>90000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Pune</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Delhi</td>
# <td>87000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Hyderabad</td>
# <td>85000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Pune</td>
# <td>78000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>70000</td>
# </tr>
#
# </table>

# %%
data = [
    ['A','Mumbai',40000],
    ['B','Pune',45000],
    ['A','Hyderabad',50000],
    ['C','Mumbai',90000],
    ['D','Pune',89000],
    ['A','Delhi',87000],
    ['D','Hyderabad',85000],
    ['A','Pune',78000],
    ['C','Mumbai',89000],
    ['B','Pune',70000]
]
col=['Store','Location','Sales']
df=pd.DataFrame(data,columns=col)
pd.pivot_table(df,values='Sales',index='Store',aggfunc='mean')
# Out:
#        Sales
# Store
# A      63750
# B      57500
# C      89500
# D      87000

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 4. Compute the average sales for each store in every city
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Store</th>
# <th>Location</th>
# <th>Sales</th>
# </tr>
# <tr>
# <td>A</td>
# <td>Mumbai</td>
# <td>40000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>45000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Hyderabad</td>
# <td>50000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>90000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Pune</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Delhi</td>
# <td>87000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Hyderabad</td>
# <td>85000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Pune</td>
# <td>78000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>70000</td>
# </tr>
#
# </table>

# %%
data = [
    ['A','Mumbai',40000],
    ['B','Pune',45000],
    ['A','Hyderabad',50000],
    ['C','Mumbai',90000],
    ['D','Pune',89000],
    ['A','Delhi',87000],
    ['D','Hyderabad',85000],
    ['A','Pune',78000],
    ['C','Mumbai',89000],
    ['B','Pune',70000]
]
col=['Store','Location','Sales']
df=pd.DataFrame(data,columns=col)
pd.pivot_table(df,values='Sales',columns='Location',index='Store',aggfunc='mean')
# Out:
# Location    Delhi  Hyderabad   Mumbai     Pune
# Store
# A         87000.0    50000.0  40000.0  78000.0
# B             NaN        NaN      NaN  57500.0
# C             NaN        NaN  89500.0      NaN
# D             NaN    85000.0      NaN  89000.0

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 5. Compute the minimum sales for each store in every city
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Store</th>
# <th>Location</th>
# <th>Sales</th>
# </tr>
# <tr>
# <td>A</td>
# <td>Mumbai</td>
# <td>40000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>45000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Hyderabad</td>
# <td>50000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>90000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Pune</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Delhi</td>
# <td>87000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Hyderabad</td>
# <td>85000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Pune</td>
# <td>78000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>70000</td>
# </tr>
#
# </table>

# %%
data = [
    ['A','Mumbai',40000],
    ['B','Pune',45000],
    ['A','Hyderabad',50000],
    ['C','Mumbai',90000],
    ['D','Pune',89000],
    ['A','Delhi',87000],
    ['D','Hyderabad',85000],
    ['A','Pune',78000],
    ['C','Mumbai',89000],
    ['B','Pune',70000]
]
col=['Store','Location','Sales']
df=pd.DataFrame(data,columns=col)
pd.pivot_table(df,values='Sales',columns='Location',index='Store',aggfunc=np.min)
# Out:
# Location    Delhi  Hyderabad   Mumbai     Pune
# Store
# A         87000.0    50000.0  40000.0  78000.0
# B             NaN        NaN      NaN  45000.0
# C             NaN        NaN  89000.0      NaN
# D             NaN    85000.0      NaN  89000.0

# %% [markdown]
# <a id='Duplicating'></a>
# ## 2. Duplicate

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 6. Find duplicate rows in the data
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Name</th>
# <th>Salary</th>
# <th>City</th>
# </tr>
# <tr>
# <td>John</td>
# <td>3400</td>
# <td>Sydeny</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
# <tr>
# <td>Aadi</td>
# <td>1600</td>
# <td>New York</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Texas</td>
# </tr>
# <tr>
# <td>Aadi</td>
# <td>4000</td>
# <td>London</td>
# </tr>
# <tr>
# <td>Sachine</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
#
# </table>

# %%
df=pd.DataFrame({'Name':['John','Robert','Aadi','Robert','Robert','Robert','Aadi','Sachine'],'Salary':[3400,3000,1600,3000,3000,3000,4000,3000],'City':['Sydney','Chicago','NewYork','Chicago','Chicago','Texas','London','Chicago']})
df[df.duplicated()]
# Out:
#      Name  Salary     City
# 3  Robert    3000  Chicago
# 4  Robert    3000  Chicago

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 7. Select duplicate rows, except the last occurrence
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Name</th>
# <th>Salary</th>
# <th>City</th>
# </tr>
# <tr>
# <td>John</td>
# <td>3400</td>
# <td>Sydeny</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
# <tr>
# <td>Aadi</td>
# <td>1600</td>
# <td>New York</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Texas</td>
# </tr>
# <tr>
# <td>Aadi</td>
# <td>4000</td>
# <td>London</td>
# </tr>
# <tr>
# <td>Sachine</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
#
# </table>

# %%
df=pd.DataFrame({'Name':['John','Robert','Aadi','Robert','Robert','Robert','Aadi','Sachine'],'Salary':[3400,3000,1600,3000,3000,3000,4000,3000],'City':['Sydney','Chicago','NewYork','Chicago','Chicago','Texas','London','Chicago']})
df[df.duplicated(keep='last')]
# Out:
#      Name  Salary     City
# 1  Robert    3000  Chicago
# 3  Robert    3000  Chicago

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 8.  Select the duplicated rows based on the column names 'Salary' and 'City'
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Name</th>
# <th>Salary</th>
# <th>City</th>
# </tr>
# <tr>
# <td>John</td>
# <td>3400</td>
# <td>Sydeny</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
# <tr>
# <td>Aadi</td>
# <td>1600</td>
# <td>New York</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Texas</td>
# </tr>
# <tr>
# <td>Aadi</td>
# <td>4000</td>
# <td>London</td>
# </tr>
# <tr>
# <td>Sachine</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
#
# </table>

# %%
df=pd.DataFrame({'Name':['John','Robert','Aadi','Robert','Robert','Robert','Aadi','Sachine'],'Salary':[3400,3000,1600,3000,3000,3000,4000,3000],'City':['Sydney','Chicago','NewYork','Chicago','Chicago','Texas','London','Chicago']})
df[df.duplicated(subset=['Salary','City'])]
# Out:
#       Name  Salary     City
# 3   Robert    3000  Chicago
# 4   Robert    3000  Chicago
# 7  Sachine    3000  Chicago

# %% [markdown]
# <a id='Replacing'></a>
# ## 3. Replace

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 9.  Replace 'football' with 'hockey' in the column tournament
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
 pd.DataFrame({'Days':['Mon','Tues','Wed','Thurs','Fri'],'Tournament':['Football','Cricket','Football','Football','Cricket']})
# Out:
#     Days Tournament
# 0    Mon   Football
# 1   Tues    Cricket
# 2    Wed   Football
# 3  Thurs   Football
# 4    Fri    Cricket

# %%
df=pd.DataFrame({'Days':['Mon','Tues','Wed','Thurs','Fri'],'Tournament':['Football','Cricket','Football','Football','Cricket']})
print(df)
df['Tournament'].replace(to_replace='Football',value='Hockey',inplace=True)
df
# Out:
#     Days Tournament
# 0    Mon   Football
# 1   Tues    Cricket
# 2    Wed   Football
# 3  Thurs   Football
# 4    Fri    Cricket
#     Days Tournament
# 0    Mon     Hockey
# 1   Tues    Cricket
# 2    Wed     Hockey
# 3  Thurs     Hockey
# 4    Fri    Cricket

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 10.  Replace all 0's with male and all 1's with female in the gender column
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Name</th>
# <th>Num_Children</th>
# <th>Gender</th>
# </tr>
# <tr>
# <td>John</td>
# <td>0</td>
# <td>0</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>4</td>
# <td>0</td>
# </tr>
# <tr>
# <td>Johny</td>
# <td>5</td>
# <td>0</td>
# </tr>
# <tr>
# <td>Mia</td>
# <td>3</td>
# <td>1</td>
# </tr>
#
# </table>

# %%
df=pd.DataFrame({'Name':['John','Robert','Johny','Mia'],'Num_children':[0,4,5,3],'Gender':[0,0,0,1]})
print(df)
df['Gender'].replace(to_replace=[0,1],value=['Male','Female'],inplace=True)
df
# Out:
#      Name  Num_children  Gender
# 0    John             0       0
# 1  Robert             4       0
# 2   Johny             5       0
# 3     Mia             3       1
#      Name  Num_children  Gender
# 0    John             0    Male
# 1  Robert             4    Male
# 2   Johny             5    Male
# 3     Mia             3  Female

# %% [markdown]
# <a id='Summary_Statistics'></a>
# ## 4. Summary Statistics

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 12.  Find the descriptive statistics for the sales column of the given dataframe
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Month</th>
# <th>Sales</th>
# <th>Seasons</th>
# </tr>
# <tr>
# <td>Jan</td>
# <td>22000</td>
# <td>Winter</td>
# </tr>
# <tr>
# <td>Feb</td>
# <td>27000</td>
# <td>Winter</td>
# </tr>
# <tr>
# <td>Mar</td>
# <td>25000</td>
# <td>Spring</td>
# </tr>
# <tr>
# <td>Apr</td>
# <td>29000</td>
# <td>Spring</td>
# </tr>
# <tr>
# <td>May</td>
# <td>35000</td>
# <td>Spring</td>
# </tr>
# <tr>
# <td>June</td>
# <td>67000</td>
# <td>Summer</td>
# </tr>
# <tr>
# <td>July</td>
# <td>78000</td>
# <td>Summer</td>
# </tr>
# <tr>
# <td>Aug</td>
# <td>67000</td>
# <td>Summer</td>
# </tr>
# <tr>
# <td>Sep</td>
# <td>56000</td>
# <td>Fall</td>
# </tr>
# <tr>
# <td>Oct</td>
# <td>56000</td>
# <td>Fall</td>
# </tr>
# <tr>
# <td>Nov</td>
# <td>56000</td>
# <td>Fall</td>
# </tr>
# <tr>
# <td>Dec</td>
# <td>60000</td>
# <td>Winter</td>
# </tr>
#
# </table>

# %%
df=pd.DataFrame({'Month':['Jan','Feb','Mar','Apr','May','June','July','Aug','Sep','Oct','Nov','Dec'],'Sales':[22000,27000,25000,29000,35000,67000,78000,67000,56000,56000,56000,60000],'Seasons':['Winter','Winter','Spring','Spring','Spring','Summer','Summer','Summer','Fall','Fall','Fall','Winter']})
df['Sales'].describe()
# Out:
# count       12.000000
# mean     48166.666667
# std      19385.249000
# min      22000.000000
# 25%      28500.000000
# 50%      56000.000000
# 75%      61750.000000
# max      78000.000000
# Name: Sales, dtype: float64

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 13.  Find the median of sales for each season
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Month</th>
# <th>Sales</th>
# <th>Seasons</th>
# </tr>
# <tr>
# <td>Jan</td>
# <td>22000</td>
# <td>Winter</td>
# </tr>
# <tr>
# <td>Feb</td>
# <td>27000</td>
# <td>Winter</td>
# </tr>
# <tr>
# <td>Mar</td>
# <td>25000</td>
# <td>Spring</td>
# </tr>
# <tr>
# <td>Apr</td>
# <td>29000</td>
# <td>Spring</td>
# </tr>
# <tr>
# <td>May</td>
# <td>35000</td>
# <td>Spring</td>
# </tr>
# <tr>
# <td>June</td>
# <td>67000</td>
# <td>Summer</td>
# </tr>
# <tr>
# <td>July</td>
# <td>78000</td>
# <td>Summer</td>
# </tr>
# <tr>
# <td>Aug</td>
# <td>67000</td>
# <td>Summer</td>
# </tr>
# <tr>
# <td>Sep</td>
# <td>56000</td>
# <td>Fall</td>
# </tr>
# <tr>
# <td>Oct</td>
# <td>56000</td>
# <td>Fall</td>
# </tr>
# <tr>
# <td>Nov</td>
# <td>56000</td>
# <td>Fall</td>
# </tr>
# <tr>
# <td>Dec</td>
# <td>60000</td>
# <td>Winter</td>
# </tr>
#
# </table>

# %%
df=pd.DataFrame({'Month':['Jan','Feb','Mar','Apr','May','June','July','Aug','Sep','Oct','Nov','Dec'],'Sales':[22000,27000,25000,29000,35000,67000,78000,67000,56000,56000,56000,60000],'Seasons':['Winter','Winter','Spring','Spring','Spring','Summer','Summer','Summer','Fall','Fall','Fall','Winter']})
df['Sales'].groupby(df['Seasons']).median()
# Out:
# Seasons
# Fall      56000
# Spring    29000
# Summer    67000
# Winter    27000
# Name: Sales, dtype: int64

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 14. Find the descriptive statistics for categorical data from the dataframe
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Month</th>
# <th>Sales</th>
# <th>Seasons</th>
# </tr>
# <tr>
# <td>Jan</td>
# <td>22000</td>
# <td>Winter</td>
# </tr>
# <tr>
# <td>Feb</td>
# <td>27000</td>
# <td>Winter</td>
# </tr>
# <tr>
# <td>Mar</td>
# <td>25000</td>
# <td>Spring</td>
# </tr>
# <tr>
# <td>Apr</td>
# <td>29000</td>
# <td>Spring</td>
# </tr>
# <tr>
# <td>May</td>
# <td>35000</td>
# <td>Spring</td>
# </tr>
# <tr>
# <td>June</td>
# <td>67000</td>
# <td>Summer</td>
# </tr>
# <tr>
# <td>July</td>
# <td>78000</td>
# <td>Summer</td>
# </tr>
# <tr>
# <td>Aug</td>
# <td>67000</td>
# <td>Summer</td>
# </tr>
# <tr>
# <td>Sep</td>
# <td>56000</td>
# <td>Fall</td>
# </tr>
# <tr>
# <td>Oct</td>
# <td>56000</td>
# <td>Fall</td>
# </tr>
# <tr>
# <td>Nov</td>
# <td>56000</td>
# <td>Fall</td>
# </tr>
# <tr>
# <td>Dec</td>
# <td>60000</td>
# <td>Winter</td>
# </tr>
#
# </table>

# %%
df=pd.DataFrame({'Month':['Jan','Feb','Mar','Apr','May','June','July','Aug','Sep','Oct','Nov','Dec'],'Sales':[22000,27000,25000,29000,35000,67000,78000,67000,56000,56000,56000,60000],'Seasons':['Winter','Winter','Spring','Spring','Spring','Summer','Summer','Summer','Fall','Fall','Fall','Winter']})
df.select_dtypes(include='object').describe()
# Out:
#        Month Seasons
# count     12      12
# unique    12       4
# top      Feb  Summer
# freq       1       3

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 15. Find the kurtosis for each subject
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Name</th>
# <th>Maths</th>
# <th>Science</th>
# <th>English</th>
# </tr>
# <tr>
# <td>Emma</td>
# <td>56</td>
# <td>89</td>
# <td>89</td>
# </tr>
# <tr>
# <td>Mia</td>
# <td>78</td>
# <td>87</td>
# <td>89</td>
# </tr>
# <tr>
# <td>Sophia</td>
# <td>78</td>
# <td>78</td>
# <td>76</td>
# </tr>
# <tr>
# <td>James</td>
# <td>67</td>
# <td>89</td>
# <td>78</td>
# </tr>
# <td>John</td>
# <td>88</td>
# <td>78</td>
# <td>87</td>
# </tr>
#
# </table>

# %%
df=pd.DataFrame({'Name':['Emma','Mia','Sophia','James','John'],'Maths':[56,78,78,67,88],'Science':[89,87,78,89,78],'English':[89,89,76,78,87]})
df.kurtosis(axis=0)
# Out:
# Maths     -0.219599
# Science   -3.232332
# English   -2.923881
# dtype: float64

# %% [markdown]
# <a id='merge'></a>
# ## 5. Merge, Join, Concatenate

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 16. Merge the given dataframes on the column 'Brand'
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>ID</th>
# <th>Brand</th>
# <th>Product</th>
# </tr>
# <tr>
# <td>101</td>
# <td>Apple</td>
# <td>iPhone</td>
# </tr>
# <tr>
# <td>102</td>
# <td>Canon</td>
# <td>DSLR</td>
# </tr>
# <tr>
# <td>103</td>
# <td>Samsung</td>
# <td>SmartPhone</td>
# </tr>
# <tr>
# <td>104</td>
# <td>Nikon</td>
# <td>DSLR</td>
# </tr>
# <td>105</td>
# <td>Sony</td>
# <td>SmartTV</td>
# </tr>
#
# </table><br>
#
# <table>
# <tr>
#     <th>ID</th>
# <th>Brand</th>
# <th>Quantity_sold</th>
# </tr>
# <tr>
#     <td>101</td>
# <td>Apple</td>
# <td>234</td>
# </tr>
# <tr>
#     <td>102</td>
# <td>Canon</td>
# <td>344</td>
# </tr>
# <tr>
#     <td>104</td>
# <td>Samsung</td>
# <td>345</td>
# </tr>
# <tr>
#     <td>103</td>
# <td>Nikon</td>
# <td>262</td>
# </tr>
#     <td>105</td>
# <td>Sony</td>
# <td>356</td>
# </tr>
# </table>

# %%
A=pd.DataFrame({'ID':[101,102,103,104,105],'Brand':['Apple','Canon','Samsung','Nikon','Sony'],'Product':['iphone','DSLR','Smartphone','DSLR','SmartTV']})
B=pd.DataFrame({'ID':[101,102,104,103,105],'Brand':['Apple','Canon','Samsung','Nikon','Sony'],'Quantity_sold':[234,344,345,262,356]})
pd.merge(A,B,on=['Brand'])
# Out:
#    ID_x    Brand     Product  ID_y  Quantity_sold
# 0   101    Apple      iphone   101            234
# 1   102    Canon        DSLR   102            344
# 2   103  Samsung  Smartphone   104            345
# 3   104    Nikon        DSLR   103            262
# 4   105     Sony     SmartTV   105            356

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 17. Using the dataframes created in question 16, merge the given dataframes by 'ID' and 'Brand'
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
A=pd.DataFrame({'ID':[101,102,103,104,105],'Brand':['Apple','Canon','Samsung','Nikon','Sony'],'Product':['iphone','DSLR','Smartphone','DSLR','SmartTV']})
B=pd.DataFrame({'ID':[101,102,104,103,105],'Brand':['Apple','Canon','Samsung','Nikon','Sony'],'Quantity_sold':[234,344,345,262,356]})
pd.merge(A,B,on=['ID','Brand'])
# Out:
#     ID  Brand  Product  Quantity_sold
# 0  101  Apple   iphone            234
# 1  102  Canon     DSLR            344
# 2  105   Sony  SmartTV            356

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 18. Using the dataframes created in question 16, perform left join to combine values in the columns 'Brand' and 'ID'
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
A=pd.DataFrame({'ID':[101,102,103,104,105],'Brand':['Apple','Canon','Samsung','Nikon','Sony'],'Product':['iphone','DSLR','Smartphone','DSLR','SmartTV']})
B=pd.DataFrame({'ID':[101,102,104,103,105],'Brand':['Apple','Canon','Samsung','Nikon','Sony'],'Quantity_sold':[234,344,345,262,356]})
pd.merge(A,B,on=['Brand','ID'],how='left')
# Out:
#     ID    Brand     Product  Quantity_sold
# 0  101    Apple      iphone          234.0
# 1  102    Canon        DSLR          344.0
# 2  103  Samsung  Smartphone            NaN
# 3  104    Nikon        DSLR            NaN
# 4  105     Sony     SmartTV          356.0

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 19. Using the dataframes created in question 16, perform outer join to combine values in the columns 'Brand' and 'ID'
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
A=pd.DataFrame({'ID':[101,102,103,104,105],'Brand':['Apple','Canon','Samsung','Nikon','Sony'],'Product':['iphone','DSLR','Smartphone','DSLR','SmartTV']})
B=pd.DataFrame({'ID':[101,102,104,103,105],'Brand':['Apple','Canon','Samsung','Nikon','Sony'],'Quantity_sold':[234,344,345,262,356]})
pd.merge(A,B,on=['Brand','ID'],how='outer')
# Out:
#     ID    Brand     Product  Quantity_sold
# 0  101    Apple      iphone          234.0
# 1  102    Canon        DSLR          344.0
# 2  103  Samsung  Smartphone            NaN
# 3  104    Nikon        DSLR            NaN
# 4  105     Sony     SmartTV          356.0
# 5  104  Samsung         NaN          345.0
# 6  103    Nikon         NaN          262.0

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 20. Concatenate rows of the given dataframes and assign the store as its key
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
#                            Products in Store_A:
# <table>
#     <tr>
#         <th>ID</th>
#         <th>Brand</th>
#         <th>Product</th>
#     </tr>
#     <tr>
#         <td>101</td>
#         <td>Apple</td>
#         <td>iPhone</td>
#         </tr>
#     <tr>
#         <td>102</td>
#         <td>Canon</td>
#         <td>DSLR</td>
#     </tr>
#     <tr>
#         <td>103</td>
#         <td>Samsung</td>
#         <td>SmartPhone</td>
#     </tr>
#     <tr>
#         <td>104</td>
#         <td>Nikon</td>
#         <td>DSLR</td>
#   </tr>
#       <td>105</td>
#       <td>Sony</td>
#       <td>SmartTV</td>
#   </tr>
# </table>

# %% [markdown]
#                           Products in Store_B:
# <table>
#     <tr>
#         <th>ID</th>
#         <th>Brand</th>
#         <th>Product</th>
#     </tr>
#     <tr>
#         <td>103</td>
#         <td>Apple</td>
#         <td>iPhone</td>
#         </tr>
#     <tr>
#         <td>104</td>
#         <td>Apple</td>
#         <td>iPod</td>
#     </tr>
#     <tr>
#         <td>104</td>
#         <td>Samsung</td>
#         <td>SmartPhone</td>
#     </tr>
#     <tr>
#         <td>107</td>
#         <td>Canon</td>
#         <td>DSLR</td>
#   </tr>
#       <td>101</td>
#       <td>Sony</td>
#       <td>SmartTV</td>
#   </tr>
# </table>

# %%
s_A=pd.DataFrame({'ID':[101,102,103,104,105],'Brand':['Apple','Canon','Samsung','Nikon','Sony'],'Product':['iphone','DSLR','Smartphone','DSLR','SmartTV']})
s_B=pd.DataFrame({'ID':[103,104,104,107,101],'Brand':['Apple','Apple','Samsung','Canon','Sony'],'Product':['iphone','ipod','Smartphone','DSLR','SmartTV']})
pd.concat(objs=(s_A,s_B),axis=0,join='inner',keys=['Products in store_A','Products in store_B'])
# Out:
#                         ID    Brand     Product
# Products in store_A 0  101    Apple      iphone
#                     1  102    Canon        DSLR
#                     2  103  Samsung  Smartphone
#                     3  104    Nikon        DSLR
#                     4  105     Sony     SmartTV
# Products in store_B 0  103    Apple      iphone
#                     1  104    Apple        ipod
#                     2  104  Samsung  Smartphone
#                     3  107    Canon        DSLR
#                     4  101     Sony     SmartTV
